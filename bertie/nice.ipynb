# %%
import pandas as pd
import numpy as np
import os
from bert_score import score

file_name = 'Data/train.tsv'
df = pd.read_csv(file_name, delimiter='\t')
# print(df) # print(df.head()) # print(df.columns) # print(len(df))
tot = df.loc[(df['EssaySet'] == 3)]
print("Total sentences: ", len(tot))

ref1 = df.loc[(df['EssaySet'] == 3) & (df['Score1'] == 2)]
# print(ref1)
ref1.reset_index(drop=True, inplace=True)
arrs = list(ref1['EssayText'])
# print(arrs[0])
print("Reference Sentences: ", len(arrs))

can1 = df.loc[(df['EssaySet'] == 3) & (df['Score1'] != 2)]
can1.reset_index(drop=True, inplace=True)
cees = list(can1['EssayText'])
# print(cees[0])
print("Candidate Sentences: ", len(cees))
# Out:
# Total sentences:  1891
# Reference Sentences:  441
# Candidate Sentences:  1450

# %%
refs = [arrs] * len(cees)
cands = cees
sol = score(cands, refs, model_type=None, num_layers=None, verbose=False,
            idf=False, device=None, batch_size=64, nthreads=4, all_layers=False,
            lang="en", return_hash=False, rescale_with_baseline=False)

print(len(sol))
# Out:
# Downloading:   0%|          | 174k/1.43G [00:15<24:33:04, 16.1kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-88610345502d> in <module>
#       3 sol = score(cands, refs, model_type=None, num_layers=None, verbose=False,
#       4             idf=False, device=None, batch_size=64, nthreads=4, all_layers=False,
# ----> 5             lang="en", return_hash=False, rescale_with_baseline=False)
#       6 print(len(sol))
#
# c:\Users\Karan\Documents\IISc\SEM2\ML\Automatic_Evaluation_Metrics\Code\my_implem\bert_score\score.py in score(cands, refs, model_type, num_layers, verbose, idf, device, batch_size, nthreads, all_layers, lang, return_hash, rescale_with_baseline)
#      86         tokenizer = AutoTokenizer.from_pretrained(model_type)
#      87
# ---> 88     model = get_model(model_type, num_layers, all_layers)
#      89     device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      90     model.to(device)
#
# c:\Users\Karan\Documents\IISc\SEM2\ML\Automatic_Evaluation_Metrics\Code\my_implem\bert_score\utils.py in get_model(model_type, num_layers, all_layers)
#      92         model = AutoModel.from_pretrained(cache_scibert(model_type))
#      93     else:
# ---> 94         model = AutoModel.from_pretrained(model_type)
#      95     model.eval()
#      96
#
# C:\Program Files\Python37\lib\site-packages\transformers\modeling_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     385         for config_class, model_class in MODEL_MAPPING.items():
#     386             if isinstance(config, config_class):
# --> 387                 return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#     388         raise ValueError(
#     389             "Unrecognized configuration class {} for this kind of AutoModel: {}.\n"
#
# C:\Program Files\Python37\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     480                     proxies=proxies,
#     481                     resume_download=resume_download,
# --> 482                     local_files_only=local_files_only,
#     483                 )
#     484             except EnvironmentError:
#
# C:\Program Files\Python37\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, local_files_only)
#     252             resume_download=resume_download,
#     253             user_agent=user_agent,
# --> 254             local_files_only=local_files_only,
#     255         )
#     256     elif os.path.exists(url_or_filename):
#
# C:\Program Files\Python37\lib\site-packages\transformers\file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only)
#     485                 s3_get(url, temp_file, proxies=proxies)
#     486             else:
# --> 487                 http_get(url, temp_file, proxies=proxies, resume_size=resume_size, user_agent=user_agent)
#     488
#     489         logger.info("storing %s in cache at %s", url, cache_path)
#
# C:\Program Files\Python37\lib\site-packages\transformers\file_utils.py in http_get(url, temp_file, proxies, resume_size, user_agent)
#     373         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     374     )
# --> 375     for chunk in response.iter_content(chunk_size=1024):
#     376         if chunk:  # filter out keep-alive new chunks
#     377             progress.update(len(chunk))
#
# C:\Program Files\Python37\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# C:\Program Files\Python37\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     562         else:
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#     566                 if data:
#
# C:\Program Files\Python37\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# C:\Program Files\Python37\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# C:\Program Files\Python37\lib\http\client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# C:\Program Files\Python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\Program Files\Python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# C:\Program Files\Python37\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
